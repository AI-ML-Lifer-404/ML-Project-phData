# %%
import pandas as pd

# %%
import numpy as np

# %%
df1 = pd.read_csv("kc_house_data.csv")

# %%
df2 = pd.read_csv("zipcode_demographics.csv")

# %%
df2
# Out:
#     ppltn_qty  urbn_ppltn_qty  sbrbn_ppltn_qty  farm_ppltn_qty  non_farm_qty  \
# 0     38249.0         37394.0              0.0             0.0         855.0
# 1     22036.0         22036.0              0.0             0.0           0.0
# 2     18194.0         18194.0              0.0             0.0           0.0
# 3     21956.0         21956.0              0.0             0.0           0.0
# 4     22814.0         22814.0              0.0             0.0           0.0
# ..        ...             ...              ...             ...           ...
# 65    35140.0         35021.0              0.0             0.0         119.0
# 66    23926.5         23298.0              0.0             0.0           0.0
# 67    23926.5         23298.0              0.0             0.0           0.0
# 68    23926.5         23298.0              0.0             0.0           0.0
# 69    23926.5         23298.0              0.0             0.0           0.0
#
# ...

# %%
df3 = pd.merge(df1, df2, on = 'zipcode')

# %%
df3.to_csv('housing_demographics.csv')

# %%
df3
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  per_sbrbn  \
# 0             1180      5650     1.0           0     0  ...        0.0
# ...

# %%
df3.set_index('zipcode', inplace = True)

# %%
df3
# Out:
#                  id             date     price  bedrooms  bathrooms  \
# zipcode
# 98178    7129300520  20141013T000000  221900.0         3       1.00
# 98125    6414100192  20141209T000000  538000.0         3       2.25
# 98028    5631500400  20150225T000000  180000.0         2       1.00
# 98136    2487200875  20141209T000000  604000.0         4       3.00
# 98074    1954400510  20150218T000000  510000.0         3       2.00
# ...             ...              ...       ...       ...        ...
# 98103     263000018  20140521T000000  360000.0         3       2.50
# 98146    6600060120  20150223T000000  400000.0         4       2.50
# 98144    1523300141  20140623T000000  402101.0         2       0.75
# 98027     291310100  20150116T000000  400000.0         3       2.50
# 98144    1523300157  20141015T000000  325000.0         2       0.75
#
#          sqft_living  sqft_lot  floors  waterfront  view  ...  per_sbrbn  \
# zipcode                                                   ...
# ...
